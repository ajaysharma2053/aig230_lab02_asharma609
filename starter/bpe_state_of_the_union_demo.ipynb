# %% [markdown]
# # AIG 230 – BPE Demo Notebook
# ## Byte Pair Encoding (BPE) with the State of the Union Corpus
#
# **Purpose of this notebook**
# This notebook demonstrates, end-to-end, how **Byte Pair Encoding (BPE)** works using a *real corpus*: the U.S. State of the Union addresses.
#
# This notebook is intentionally simple and conceptual. It exists to build correct mental models about subword tokenization.

# %% [markdown]
# ## 1. Setup
#
# We use:
# - NLTK to access the State of the Union corpus
# - Hugging Face `tokenizers` to train a simple BPE tokenizer

# %%
# Install if needed
# !pip install nltk tokenizers

import nltk
from nltk.corpus import state_union

nltk.download("state_union")
# Out:
# [nltk_data] Downloading package state_union to
# [nltk_data]     C:\Users\david\AppData\Roaming\nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# True

# %% [markdown]
# ## 2. Load and Inspect the Corpus

# %%
fileids = state_union.fileids()
len(fileids), fileids[:5]
# Out:
# (65,
#  ['1945-Truman.txt',
#   '1946-Truman.txt',
#   '1947-Truman.txt',
#   '1948-Truman.txt',
#   '1949-Truman.txt'])

# %%
texts = [state_union.raw(fid) for fid in fileids[:10]]
corpus_text = "\n".join(texts)

corpus_text[:500]
# Out:
# "PRESIDENT HARRY S. TRUMAN'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS\n \nApril 16, 1945\n\nMr. Speaker, Mr. President, Members of the Congress:\nIt is with a heavy heart that I stand before you, my friends and colleagues, in the Congress of the United States.\nOnly yesterday, we laid to rest the mortal remains of our beloved President, Franklin Delano Roosevelt. At a time like this, words are inadequate. The most eloquent tribute would be a reverent silence.\nYet, in this decisive hour, when worl"

# %% [markdown]
# ## 3. Why BPE?
#
# BPE learns **subword units** from data instead of relying on predefined words.

# %% [markdown]
# ## 4. Train a Simple BPE Tokenizer

# %%
# !pip install tokenizers
# Out:
# Collecting tokenizers
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers)
#   Downloading huggingface_hub-1.3.2-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Downloading filelock-3.20.3-py3-none-any.whl.metadata (2.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Downloading fsspec-2026.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\david\aig230-env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\david\aig230-env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\david\aig230-env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (6.0.3)
# Collecting shellingham (from huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\david\aig230-env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (4.67.1)
# Requirement already satisfied: typer-slim in c:\users\david\aig230-env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\david\aig230-env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\david\aig230-env\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (4.12.1)
# Requirement already satisfied: certifi in c:\users\david\aig230-env\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\david\aig230-env\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (1.0.9)
# Requirement already satisfied: idna in c:\users\david\aig230-env\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\david\aig230-env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (0.16.0)
# Requirement already satisfied: colorama in c:\users\david\aig230-env\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.16.4->tokenizers) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\david\aig230-env\lib\site-packages (from typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers) (8.3.1)
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 39.5 MB/s  0:00:00
# Downloading huggingface_hub-1.3.2-py3-none-any.whl (534 kB)
#    ---------------------------------------- 0.0/534.5 kB ? eta -:--:--
#    ---------------------------------------- 534.5/534.5 kB 17.0 MB/s  0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 21.1 MB/s  0:00:00
# Downloading fsspec-2026.1.0-py3-none-any.whl (201 kB)
# Downloading filelock-3.20.3-py3-none-any.whl (16 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: shellingham, hf-xet, fsspec, filelock, huggingface-hub, tokenizers
#
#    ------------- -------------------------- 2/6 [fsspec]
#    ------------- -------------------------- 2/6 [fsspec]
#    -------------------- ------------------- 3/6 [filelock]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    --------------------------------- ------ 5/6 [tokenizers]
#    ---------------------------------------- 6/6 [tokenizers]
#
# Successfully installed filelock-3.20.3 fsspec-2026.1.0 hf-xet-1.2.0 huggingface-hub-1.3.2 shellingham-1.5.4 tokenizers-0.22.2

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace

tokenizer = Tokenizer(BPE(unk_token="[UNK]"))
tokenizer.pre_tokenizer = Whitespace()

trainer = BpeTrainer(
    vocab_size=200,
    special_tokens=["[UNK]", "[PAD]", "[CLS]", "[SEP]", "[MASK]"]
)

tokenizer.train_from_iterator([corpus_text], trainer=trainer)

# %% [markdown]
# ## 5. Inspect the Learned Vocabulary

# %%
vocab = tokenizer.get_vocab()
list(vocab.items())[:30]
# Out:
# [('0', 16),
#  ('ac', 123),
#  ('am', 153),
#  ('ut', 186),
#  ('L', 40),
#  ('O', 43),
#  ('J', 38),
#  ('[MASK]', 4),
#  ('/', 15),
#  ('com', 148),
#  ('le', 118),
#  ('v', 77),
#  ('ion', 97),
#  ('ec', 114),
#  ('ig', 160),
#  ('pe', 154),
#  ('ive', 173),
#  ('?', 28),
#  ('no', 190),
#  ('Z', 54),
#  ('he', 128),
#  ('re', 86),
#  ('N', 42),
#  ('se', 125),
#  ('id', 170),
#  ('ad', 162),
#  ('ist', 193),
#  ('pr', 172),
#  ('r', 73),
#  ('un', 136)]

# %% [markdown]
# ## 6. BPE Tokenization Example

# %%
sentence = "Democracy and democratic institutions must be protected."
tokenizer.encode(sentence).tokens
# Out:
# ['D',
#  'e',
#  'mo',
#  'c',
#  'r',
#  'ac',
#  'y',
#  'and',
#  'de',
#  'mo',
#  'c',
#  'r',
#  'at',
#  'ic',
#  'in',
#  'st',
#  'it',
#  'u',
#  'tion',
#  's',
#  'm',
#  'ust',
#  'be',
#  'pro',
#  't',
#  'ec',
#  't',
#  'ed',
#  '.']

# %% [markdown]
# ## 7. Key Takeaways
#
# - BPE tokenization is **learned from data**
# - It captures shared structure across related words
# - It is used by modern language models
# - It is intentionally outside NLTK and spaCy
